# %%
import re

# %%
import re
content = 'Hello 123 4567 World_This is a Regex Demo'
re.match('^Hello\s\d\d\d\s\d{4}\s.*',content)
# Out:
# <_sre.SRE_Match object; span=(0, 41), match='Hello 123 4567 World_This is a Regex Demo'>

# %%
import re
content = 'Hello 123 4567 World_This is a Regex Demo'
re.match('^Hello\s\d{3}\s\d{4}\s\w{10}.*',content)
# Out:
# <_sre.SRE_Match object; span=(0, 41), match='Hello 123 4567 World_This is a Regex Demo'>

# %%
import re
content = 'Hello 123 4567 World_This is a Regex Demo'
test = re.match('^Hello\s\d{3}\s\d{4}\s\w{10}.*',content)
test.group()
# Out:
# 'Hello 123 4567 World_This is a Regex Demo'

# %%
import re
content = 'Hello 123 4567 World_This is a Regex Demo'
result = re.match('^H.*',content)
result
# Out:
# <_sre.SRE_Match object; span=(0, 41), match='Hello 123 4567 World_This is a Regex Demo'>

# %%
import re
content = 'Joker is a good man'
result = re.match('^J.*',content)
result
# Out:
# <_sre.SRE_Match object; span=(0, 19), match='Joker is a good man'>

# %%
import re
content = 'Joker is a good man'
result = re.match('^Joker\s\w{2}\s\w{1}.*',content)
result
# Out:
# <_sre.SRE_Match object; span=(0, 19), match='Joker is a good man'>

# %%
import re
content = 'Hello 123 4567 World_This is a Regex Demo'
result = re.match('^Hello.*\s(\d{4})',content)
result.group(1)
# Out:
# '4567'

# %%
import re
content = 'Hello 123 4567 World_This is a Regex Demo'
result = re.match('^Hello.*\s(\d{4})\s.*a\s(\w+)',content)
print(result.group(1))
print(result.group(2))
# Out:
# 4567
# Regex

# %%
import re
content = 'Joker is 213 a bad 123 man and hahah'
result = re.match('^Joker.*(\d{3})\s.*d\s(\d{3})\s.*d\s(\S{5})',content)
print(result.group(1))
print(result.group(2))
print(result.group(3))
# Out:
# 213
# 123
# hahah

# %%
import re
content = 'Hello 1234567 World_This is a Regex Demo'
result = re.match('^Hello.*?(\d+)',content)
print(result.group(1))
# Out:
# 1234567

# %%
import re
content = 'Hello 1234567 World_This is a Regex Demo'
result = re.match('^Hello.*?(\d+).*Demo$',content)
print(result.group(1))
# Out:
# 1234567

# %%
import re
content = 'Hello 1234567 World_This is a Regex Demo'
result = re.match('^H.*?\d\d(\d+)\d\d',content)
print(result.group(1))
# Out:
# 345

# %%
import re
content = '''Hello 1234567 World_This 
is a Regex Demo'''
result = re.match('^H.*',content,re.S)
print(result)
# Out:
# <_sre.SRE_Match object; span=(0, 41), match='Hello 1234567 World_This \nis a Regex Demo'>

# %%
import re
content = 'price is $5.00'
result = re.match('^p.*',content)
result
# Out:
# <_sre.SRE_Match object; span=(0, 14), match='price is $5.00'>

# %%
import re
content = 'price is $5.00'
result = re.match('^p.*\$(\d+\.\d+)',content)
print(result.group(1))
# Out:
# 5.00

# %%
import re
content = 'price is $5.0d0s123+'
result = re.match('^p.*\$(\d+\.\d.*)',content)
print(result.group(1))
# Out:
# 5.0d0s123+

# %%
import re
content = 'Extra strings Hello 1234567 World_This is a Regex Demo Extra strings'
result = re.search('.*',content)
print(result.group())
# Out:
# Extra strings Hello 1234567 World_This is a Regex Demo Extra strings

# %%
import re
content = 'Extra strings Hello 1234567 World_This is a Regex Demo Extra strings'
result = re.search('.*\s(\d+)',content)
print(result.group(1))
# Out:
# 1234567

# %%
import re
html = '''
</textarea></div><div id=bottom_container class=s-bottom-ctner>
<div class="ftCon-Wrapper"> <div class=qrcode-layer>
<div class="qrcode-item qrcode-item-1">
<div class=qrcode-img></div><div class=qrcode-text>
<p><b>手机百度</b></p ><p><span>快人一步</span></p >
</div> </div><div class="qrcode-item qrcode-item-2">
<div class=qrcode-img></div><div class=qrcode-text>
<p><b>百度糯米</b></p ><p><span>我的生活</span></p >
</div> </div> </div> <div class=no-qrcode-layer>
<div>
<p class=lh>
<a class=sethome href= > 设为首页 </a ></p >
<span class=copyright-text><span>&#169;2018&nbsp;Baidu&nbsp;</span><a href=//www.baidu.com/duty/ target=_blank>
使用百度前必读</a >&nbsp;
'''
result = re.search('.*>(\w+).*>(\w+).*>(\w+).*>(\w+)',html,re.S)
print(result.group(1))
print(result.group(2))
print(result.group(3))
print(result.group(4))
# Out:
# 手机百度
# 快人一步
# 百度糯米
# 我的生活

# %%
import re
html = '''
</textarea></div><div id=bottom_container class=s-bottom-ctner>
<div class="ftCon-Wrapper"> <div class=qrcode-layer>
<div class="qrcode-item qrcode-item-1">
<div class=qrcode-img></div><div class=qrcode-text>
<p><b>手机百度</b></p ><p><span>快人一步</span></p >
</div> </div><div class="qrcode-item qrcode-item-2">
<div class=qrcode-img></div><div class=qrcode-text>
<p><b>百度糯米</b></p ><p><span>我的生活</span></p >
</div> </div> </div> <div class=no-qrcode-layer>
<div>
<p class=lh>
<a class=sethome href= > 设为首页 </a ></p >
<span class=copyright-text><span>&#169;2018&nbsp;Baidu&nbsp;</span><a href=//www.baidu.com/duty/ target=_blank>
使用百度前必读</a >&nbsp;
'''
result = re.findall('<p><b>(.*)</b></p ><p><span>(.*)</span></p >',html)
print(result)
# Out:
# [('手机百度', '快人一步'), ('百度糯米', '我的生活')]

# %%
import re
html = '''
</textarea></div><div id=bottom_container class=s-bottom-ctner>
<div class="ftCon-Wrapper"> <div class=qrcode-layer>
<div class="qrcode-item qrcode-item-1">
<div class=qrcode-img></div><div class=qrcode-text>
<p><b>手机百度</b></p ><p><span>快人一步</span></p >
</div> </div><div class="qrcode-item qrcode-item-2">
<div class=qrcode-img></div><div class=qrcode-text>
<p><b>百度糯米</b></p ><p><span>我的生活</span></p >
</div> </div> </div> <div class=no-qrcode-layer>
<div>
<p class=lh>
<a class=sethome href= > 设为首页 </a ></p >
<span class=copyright-text><span>&#169;2018&nbsp;Baidu&nbsp;</span><a href=//www.baidu.com/duty/ target=_blank>
使用百度前必读</a >&nbsp;
'''
result = re.search('.*href=(.*?) target=_blank>',html,re.S)
print(result.group(1))
# Out:
# //www.baidu.com/duty/

# %%
import re
html = '''
</textarea></div><div id=bottom_container class=s-bottom-ctner>
<div class="ftCon-Wrapper"> <div class=qrcode-layer>
<div class="qrcode-item qrcode-item-1">
<div class=qrcode-img></div><div class=qrcode-text>
<p><b>手机百度</b></p ><p><span>快人一步</span></p >
</div> </div><div class="qrcode-item qrcode-item-2">
<div class=qrcode-img></div><div class=qrcode-text>
<p><b>百度糯米</b></p ><p><span>我的生活</span></p >
</div> </div> </div> <div class=no-qrcode-layer>
<div>
<p class=lh>
<a class=sethome href= > 设为首页 </a ></p >
<span class=copyright-text><span>&#169;2018&nbsp;Baidu&nbsp;</span><a href=//www.baidu.com/duty/ target=_blank>
使用百度前必读</a >&nbsp;
'''
result = re.search('<a\shref=(.*) target=_blank>',html,re.S)
print(result.group(1))
# Out:
# //www.baidu.com/duty/

# %%
import requests
response = requests.get('http://news.baidu.com/')
with open('C:/Users/lenovo/Desktop/abc.txt','w',encoding = 'utf-8') as f:
    f.write(response.text)

# %%
import re
url = 'http://news.baidu.com/'
header = ('User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36')
print(response.text)
# Out:
# <!doctype html>
# <html class="expanded">
# <head>
#
# <!--STATUS OK-->
# <meta http-equiv=Content-Type content="text/html;charset=utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1">
# <link rel="icon" href="//gss0.bdstatic.com/5foIcy0a2gI2n2jgoY3K/static/fisp_static/common/img/favicon.ico" mce_href="../static/img/favicon.ico" type="image/x-icon">
#
# <title>百度新闻——全球最大的中文新闻平台</title>
# <meta name="description" content="百度新闻是包含海量资讯的新闻服务平台，真实反映每时每刻的新闻热点。您可以搜索新闻事件、热点话题、人物动态、产品资讯等，快速了解它们的最新进展。" >
# <script type="text/javascript">
# 		document.write("<script  type='text/javascript' src='//news.baidu.com/z/resource/pc_index_banner/pcconf.js?"+new Date().getTime()+"'><\/script>");
# 	</script>
# <script type="text/javascript"> window.NEWSLOGURL = 'https://log.news.baidu.com/v.gif'; window.HUNTERLOGURL = '//log.news.baidu.com/u.gif'; window._hmt = window._hmt || [];</script>
# ...

# %%
with open = 'C:/Users/lenovo/Desktop/abc.txt'
import re
a = response.text
result = re.findall('<a\shref="(.*?)\\"',a)
print(result)
# Out:
#   File "<ipython-input-56-a67dda720465>", line 1
#     with open = 'C:/Users/lenovo/Desktop/abc.txt'
#               ^
# SyntaxError: invalid syntax
